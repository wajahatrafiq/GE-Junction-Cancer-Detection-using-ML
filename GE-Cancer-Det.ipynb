# %% [markdown]
# # Import Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
df = pd.read_csv(r"E:\GE-CancerN.csv")

# %%
df.head(10)
# Out:
#    S.no  avg rad  avg texture  avg perimeter  avg area  avg smoothness  \
# 0     0    17.99        10.38         122.80    1001.0         0.11840
# 1     1    20.57        17.77         132.90    1326.0         0.08474
# 2     2    19.69        21.25         130.00    1203.0         0.10960
# 3     3    11.42        20.38          77.58     386.1         0.14250
# 4     4    20.29        14.34         135.10    1297.0         0.10030
# 5     5    12.45        15.70          82.57     477.1         0.12780
# 6     6    18.25        19.98         119.60    1040.0         0.09463
# 7     7    13.71        20.83          90.20     577.9         0.11890
# 8     8    13.00        21.82          87.50     519.8         0.12730
# 9     9    12.46        24.04          83.97     475.9         0.11860
#
#    avg density  avg symmetry  avg fractal dimension  rad err  ...  \
# 0      0.27760        0.2419                0.07871   1.0950  ...
# 1      0.07864        0.1812                0.05667   0.5435  ...
# 2      0.15990        0.2069                0.05999   0.7456  ...
# 3      0.28390        0.2597                0.09744   0.4956  ...
# 4      0.13280        0.1809                0.05883   0.7572  ...
# 5      0.17000        0.2087                0.07613   0.3345  ...
# 6      0.10900        0.1794                0.05742   0.4467  ...
# 7      0.16450        0.2196                0.07451   0.5835  ...
# 8      0.19320        0.2350                0.07389   0.3063  ...
# 9      0.23960        0.2030                0.08243   0.2976  ...
#
#    fractal dimension err  critical rad  critical texture  critical perimeter  \
# 0               0.006193         25.38             17.33              184.60
# 1               0.003532         24.99             23.41              158.80
# 2               0.004571         23.57             25.53              152.50
# 3               0.009208         14.91             26.50               98.87
# 4               0.005115         22.54             16.67              152.20
# 5               0.005082         15.47             23.75              103.40
# 6               0.002179         22.88             27.66              153.20
# 7               0.005412         17.06             28.14              110.60
# 8               0.003749         15.49             30.73              106.20
# 9               0.010080         15.09             40.68               97.65
#
#    critical area  critical smoothness  critical density  critical symmetry  \
# 0         2019.0               0.1622            0.6656             0.4601
# 1         1956.0               0.1238            0.1866             0.2750
# 2         1709.0               0.1444            0.4245             0.3613
# 3          567.7               0.2098            0.8663             0.6638
# 4         1575.0               0.1374            0.2050             0.2364
# 5          741.6               0.1791            0.5249             0.3985
# 6         1606.0               0.1442            0.2576             0.3063
# 7          897.0               0.1654            0.3682             0.3196
# 8          739.3               0.1703            0.5401             0.4378
# 9          711.4               0.1853            1.0580             0.4366
#
#    critical fractal dimension  target
# 0                     0.11890       0
# 1                     0.08902       0
# 2                     0.08758       0
# 3                     0.17300       0
# 4                     0.07678       0
# 5                     0.12440       0
# 6                     0.08368       0
# 7                     0.11510       0
# 8                     0.10720       0
# 9                     0.20750       0
#
# [10 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   S.no                        499 non-null    int64
#  1   avg rad                     499 non-null    float64
#  2   avg texture                 499 non-null    float64
#  3   avg perimeter               499 non-null    float64
#  4   avg area                    499 non-null    float64
#  5   avg smoothness              499 non-null    float64
#  6   avg density                 499 non-null    float64
#  7   avg symmetry                499 non-null    float64
#  8   avg fractal dimension       499 non-null    float64
#  9   rad err                     499 non-null    float64
#  10  texture err                 499 non-null    float64
#  11  perimeter err               499 non-null    float64
#  12  area err                    499 non-null    float64
#  13  smoothness err              499 non-null    float64
#  14  symmetry err                499 non-null    float64
#  15  fractal dimension err       499 non-null    float64
#  16  critical rad                499 non-null    float64
#  17  critical texture            499 non-null    float64
#  18  critical perimeter          499 non-null    float64
#  19  critical area               499 non-null    float64
#  20  critical smoothness         499 non-null    float64
#  21  critical density            499 non-null    float64
#  22  critical symmetry           499 non-null    float64
#  23  critical fractal dimension  499 non-null    float64
#  24  target                      499 non-null    int64
# dtypes: float64(23), int64(2)
# memory usage: 97.6 KB

# %%
df.describe()
# Out:
#              S.no     avg rad  avg texture  avg perimeter     avg area  \
# count  499.000000  499.000000   499.000000     499.000000   499.000000
# mean   249.000000   14.211449    19.082004      92.516052   661.527856
# std    144.193157    3.468564     4.167902      23.921803   348.463270
# min      0.000000    6.981000     9.710000      43.790000   143.500000
# 25%    124.500000   11.805000    16.070000      75.900000   430.000000
# 50%    249.000000   13.430000    18.660000      86.600000   555.100000
# 75%    373.500000   16.090000    21.565000     106.000000   799.400000
# max    498.000000   28.110000    39.280000     188.500000  2501.000000
#
#        avg smoothness  avg density  avg symmetry  avg fractal dimension  \
# count      499.000000   499.000000    499.000000             499.000000
# mean         0.095953     0.103827      0.181363               0.062498
# std          0.013669     0.053080      0.027743               0.006873
# min          0.062510     0.019380      0.116700               0.049960
# 25%          0.085985     0.063515      0.161850               0.057585
# 50%          0.095790     0.090970      0.179400               0.061280
# 75%          0.105000     0.130450      0.195650               0.065760
# max          0.144700     0.345400      0.304000               0.097440
#
#           rad err  ...  fractal dimension err  critical rad  critical texture  \
# count  499.000000  ...             499.000000    499.000000        499.000000
# mean     0.409374  ...               0.003771     16.407074         25.497976
# std      0.282226  ...               0.002720      4.799700          6.064644
# min      0.111500  ...               0.000895      7.930000         12.020000
# 25%      0.233650  ...               0.002201     13.095000         21.005000
# 50%      0.327600  ...               0.003114     14.980000         25.220000
# 75%      0.490950  ...               0.004469     19.230000         29.295000
# max      2.873000  ...               0.029840     36.040000         49.540000
#
#        critical perimeter  critical area  critical smoothness  \
# count          499.000000     499.000000           499.000000
# mean           108.148216     894.271743             0.131943
# std             33.254942     570.332259             0.022753
# min             50.410000     185.200000             0.071170
# 25%             84.555000     522.300000             0.116200
# 50%             97.960000     689.100000             0.131200
# 75%            127.100000    1144.000000             0.145650
# max            251.200000    4254.000000             0.222600
#
#        critical density  critical symmetry  critical fractal dimension  \
# count        499.000000         499.000000                  499.000000
# mean           0.256117           0.292301                    0.083765
# std            0.159239           0.063399                    0.018124
# min            0.027290           0.156500                    0.055040
# 25%            0.145850           0.252000                    0.071270
# 50%            0.214100           0.283300                    0.079870
# 75%            0.342450           0.320100                    0.092070
# max            1.058000           0.663800                    0.207500
#
#            target
# count  499.000000
# mean     0.611222
# std      0.487962
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000
#
# [8 rows x 25 columns]

# %%
corr = df.corr()
corr
# Out:
#                                 S.no   avg rad  avg texture  avg perimeter  \
# S.no                        1.000000 -0.073347    -0.024000      -0.084990
# avg rad                    -0.073347  1.000000     0.362086       0.997708
# avg texture                -0.024000  0.362086     1.000000       0.367892
# avg perimeter              -0.084990  0.997708     0.367892       1.000000
# avg area                   -0.070293  0.987221     0.355452       0.986345
# avg smoothness             -0.274614  0.185293     0.034104       0.223593
# avg density                -0.225336  0.512540     0.267879       0.564955
# avg symmetry               -0.229514  0.146182     0.095190       0.182592
# avg fractal dimension      -0.174437 -0.298474    -0.054638      -0.245772
# rad err                    -0.133297  0.671140     0.297332       0.685372
# texture err                -0.010401 -0.077214     0.360486      -0.064935
# perimeter err              -0.123275  0.664775     0.299072       0.685435
# area err                   -0.085247  0.727019     0.281727       0.737363
# smoothness err             -0.066526 -0.174757     0.010349      -0.153708
# symmetry err               -0.111226 -0.083057     0.006431      -0.058617
# fractal dimension err      -0.112062 -0.029297     0.060816       0.008472
# critical rad               -0.117615  0.966672     0.395853       0.966715
# critical texture           -0.051643  0.326617     0.907319       0.332154
# critical perimeter         -0.121796  0.962346     0.399040       0.967916
# critical area              -0.106446  0.937875     0.383370       0.938507
# critical smoothness        -0.257978  0.153960     0.137012       0.184942
# critical density           -0.210090  0.407109     0.296717       0.450439
# critical symmetry          -0.245019  0.166134     0.135000       0.191830
# critical fractal dimension -0.216822  0.020059     0.140985       0.064414
# target                      0.299575 -0.724350    -0.453141      -0.737358
#
#                             avg area  avg smoothness  avg density  \
# S.no                       -0.070293       -0.274614    -0.225336
# avg rad                     0.987221        0.185293     0.512540
# avg texture                 0.355452        0.034104     0.267879
# avg perimeter               0.986345        0.223593     0.564955
# avg area                    1.000000        0.194441     0.503114
# avg smoothness              0.194441        1.000000     0.658750
# avg density                 0.503114        0.658750     1.000000
# avg symmetry                0.149325        0.553913     0.600326
# avg fractal dimension      -0.270980        0.566457     0.569175
# rad err                     0.723851        0.329156     0.507683
# texture err                -0.044446        0.098142     0.069863
# perimeter err               0.716968        0.320379     0.557329
# area err                    0.792474        0.269094     0.460813
# smoothness err             -0.121342        0.341312     0.145993
# symmetry err               -0.053698        0.226906     0.254657
# fractal dimension err      -0.008166        0.264971     0.501982
# critical rad                0.958747        0.235950     0.543536
# critical texture            0.314591        0.090255     0.268666
# critical perimeter          0.955273        0.262086     0.598868
# critical area               0.955245        0.229478     0.515389
# critical smoothness         0.156391        0.802656     0.560857
# critical density            0.383149        0.486084     0.867413
# critical symmetry           0.143050        0.415195     0.518190
# critical fractal dimension  0.014081        0.494793     0.683912
# target                     -0.699362       -0.397728    -0.607791
#
#                             avg symmetry  avg fractal dimension   rad err  \
# S.no                           -0.229514              -0.174437 -0.133297
# avg rad                         0.146182              -0.298474  0.671140
# avg texture                     0.095190              -0.054638  0.297332
# avg perimeter                   0.182592              -0.245772  0.685372
# avg area                        0.149325              -0.270980  0.723851
# avg smoothness                  0.553913               0.566457  0.329156
# avg density                     0.600326               0.569175  0.507683
# avg symmetry                    1.000000               0.482347  0.311064
# avg fractal dimension           0.482347               1.000000  0.027823
# rad err                         0.311064               0.027823  1.000000
# texture err                     0.173612               0.199527  0.238920
# perimeter err                   0.322331               0.067362  0.972312
# area err                        0.228665              -0.068776  0.950626
# smoothness err                  0.190473               0.367849  0.209423
# symmetry err                    0.464550               0.364139  0.254310
# fractal dimension err           0.321677               0.684155  0.246771
# critical rad                    0.186469              -0.235096  0.704965
# critical texture                0.113128              -0.030690  0.208265
# critical perimeter              0.220768              -0.186079  0.711119
# critical area                   0.177960              -0.215615  0.740369
# critical smoothness             0.408818               0.464874  0.168056
# critical density                0.470871               0.481958  0.286267
# critical symmetry               0.700930               0.350639  0.089288
# critical fractal dimension      0.427803               0.762480  0.063710
# target                         -0.332206              -0.016319 -0.555760
#
#                             ...  fractal dimension err  critical rad  \
# S.no                        ...              -0.112062     -0.117615
# avg rad                     ...              -0.029297      0.966672
# avg texture                 ...               0.060816      0.395853
# avg perimeter               ...               0.008472      0.966715
# avg area                    ...              -0.008166      0.958747
# avg smoothness              ...               0.264971      0.235950
# avg density                 ...               0.501982      0.543536
# avg symmetry                ...               0.321677      0.186469
# avg fractal dimension       ...               0.684155     -0.235096
# rad err                     ...               0.246771      0.704965
# texture err                 ...               0.305704     -0.092139
# perimeter err               ...               0.259363      0.684377
# area err                    ...               0.140194      0.745827
# smoothness err              ...               0.414176     -0.188269
# symmetry err                ...               0.376865     -0.115581
# fractal dimension err       ...               1.000000     -0.025166
# critical rad                ...              -0.025166      1.000000
# critical texture            ...              -0.003718      0.398156
# critical perimeter          ...               0.010254      0.993538
# critical area               ...              -0.012774      0.983539
# critical smoothness         ...               0.130846      0.260730
# critical density            ...               0.386032      0.474016
# critical symmetry           ...               0.105406      0.246496
# critical fractal dimension  ...               0.570402      0.113703
# target                      ...              -0.083454     -0.773222
#
#                             critical texture  critical perimeter  \
# S.no                               -0.051643           -0.121796
# avg rad                             0.326617            0.962346
# avg texture                         0.907319            0.399040
# avg perimeter                       0.332154            0.967916
# avg area                            0.314591            0.955273
# avg smoothness                      0.090255            0.262086
# avg density                         0.268666            0.598868
# avg symmetry                        0.113128            0.220768
# avg fractal dimension              -0.030690           -0.186079
# rad err                             0.208265            0.711119
# texture err                         0.382792           -0.081038
# perimeter err                       0.209073            0.709919
# area err                            0.211182            0.751330
# smoothness err                     -0.074863           -0.173318
# symmetry err                       -0.082898           -0.089323
# fractal dimension err              -0.003718            0.010254
# critical rad                        0.398156            0.993538
# critical texture                    1.000000            0.400528
# critical perimeter                  0.400528            1.000000
# critical area                       0.381892            0.977088
# critical smoothness                 0.288358            0.280006
# critical density                    0.372627            0.526638
# critical symmetry                   0.263691            0.272218
# critical fractal dimension          0.241514            0.156365
# target                             -0.482842           -0.779491
#
#                             critical area  critical smoothness  \
# S.no                            -0.106446            -0.257978
# avg rad                          0.937875             0.153960
# avg texture                      0.383370             0.137012
# avg perimeter                    0.938507             0.184942
# avg area                         0.955245             0.156391
# avg smoothness                   0.229478             0.802656
# avg density                      0.515389             0.560857
# avg symmetry                     0.177960             0.408818
# avg fractal dimension           -0.215615             0.464874
# rad err                          0.740369             0.168056
# texture err                     -0.063231            -0.059739
# perimeter err                    0.717102             0.151867
# area err                         0.800771             0.147799
# smoothness err                  -0.144857             0.285013
# symmetry err                    -0.101322            -0.015544
# fractal dimension err           -0.012774             0.130846
# critical rad                     0.983539             0.260730
# critical texture                 0.381892             0.288358
# critical perimeter               0.977088             0.280006
# critical area                    1.000000             0.249341
# critical smoothness              0.249341             1.000000
# critical density                 0.435581             0.583107
# critical symmetry                0.209534             0.505571
# critical fractal dimension       0.096584             0.604936
# target                          -0.725754            -0.468578
#
#                             critical density  critical symmetry  \
# S.no                               -0.210090          -0.245019
# avg rad                             0.407109           0.166134
# avg texture                         0.296717           0.135000
# avg perimeter                       0.450439           0.191830
# avg area                            0.383149           0.143050
# avg smoothness                      0.486084           0.415195
# avg density                         0.867413           0.518190
# avg symmetry                        0.470871           0.700930
# avg fractal dimension               0.481958           0.350639
# rad err                             0.286267           0.089288
# texture err                        -0.082338          -0.096018
# perimeter err                       0.337317           0.104051
# area err                            0.278054           0.068403
# smoothness err                     -0.046265          -0.103391
# symmetry err                        0.071396           0.391913
# fractal dimension err               0.386032           0.105406
# critical rad                        0.474016           0.246496
# critical texture                    0.372627           0.263691
# critical perimeter                  0.526638           0.272218
# critical area                       0.435581           0.209534
# critical smoothness                 0.583107           0.505571
# critical density                    1.000000           0.616371
# critical symmetry                   0.616371           1.000000
# critical fractal dimension          0.821708           0.542913
# target                             -0.592568          -0.422167
#
#                             critical fractal dimension    target
# S.no                                         -0.216822  0.299575
# avg rad                                       0.020059 -0.724350
# avg texture                                   0.140985 -0.453141
# avg perimeter                                 0.064414 -0.737358
# avg area                                      0.014081 -0.699362
# avg smoothness                                0.494793 -0.397728
# avg density                                   0.683912 -0.607791
# avg symmetry                                  0.427803 -0.332206
# avg fractal dimension                         0.762480 -0.016319
# rad err                                       0.063710 -0.555760
# texture err                                  -0.029400 -0.003302
# perimeter err                                 0.094410 -0.542310
# area err                                      0.027998 -0.531550
# smoothness err                                0.068124  0.029609
# symmetry err                                  0.077526 -0.002611
# fractal dimension err                         0.570402 -0.083454
# critical rad                                  0.113703 -0.773222
# critical texture                              0.241514 -0.482842
# critical perimeter                            0.156365 -0.779491
# critical area                                 0.096584 -0.725754
# critical smoothness                           0.604936 -0.468578
# critical density                              0.821708 -0.592568
# critical symmetry                             0.542913 -0.422167
# critical fractal dimension                    1.000000 -0.344343
# target                                       -0.344343  1.000000
#
# [25 rows x 25 columns]

# %%
plt.figure(figsize=(15, 15))
sns.heatmap(corr, annot=True)
# Out:
# <AxesSubplot:>

# %%
df.shape
# Out:
# (499, 25)

# %%
df['target'].value_counts()
# Out:
# 1    305
# 0    194
# Name: target, dtype: int64

# %%
df['target'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
sns.boxplot(df['avg perimeter'])
# Out:
# C:\Users\syedw\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='avg perimeter'>

# %%
 df.drop('S.no',axis=1)
# Out:
#      avg rad  avg texture  avg perimeter  avg area  avg smoothness  \
# 0      17.99        10.38         122.80    1001.0         0.11840
# 1      20.57        17.77         132.90    1326.0         0.08474
# 2      19.69        21.25         130.00    1203.0         0.10960
# 3      11.42        20.38          77.58     386.1         0.14250
# 4      20.29        14.34         135.10    1297.0         0.10030
# ..       ...          ...            ...       ...             ...
# 494    13.16        20.54          84.06     538.7         0.07335
# 495    14.87        20.21          96.12     680.9         0.09587
# 496    12.65        18.17          82.69     485.6         0.10760
# 497    12.47        17.31          80.45     480.1         0.08928
# 498    18.49        17.52         121.30    1068.0         0.10120
#
#      avg density  avg symmetry  avg fractal dimension  rad err  texture err  \
# 0        0.27760        0.2419                0.07871   1.0950       0.9053
# 1        0.07864        0.1812                0.05667   0.5435       0.7339
# 2        0.15990        0.2069                0.05999   0.7456       0.7869
# 3        0.28390        0.2597                0.09744   0.4956       1.1560
# 4        0.13280        0.1809                0.05883   0.7572       0.7813
# ..           ...           ...                    ...      ...          ...
# 494      0.05275        0.1713                0.05888   0.3237       1.4730
# 495      0.08345        0.1487                0.05748   0.2323       1.6360
# 496      0.13340        0.1641                0.06854   0.2324       0.6332
# 497      0.07630        0.1526                0.06046   0.1532       0.7810
# 498      0.13170        0.1832                0.06697   0.7923       1.0450
#
#      ...  fractal dimension err  critical rad  critical texture  \
# 0    ...               0.006193         25.38             17.33
# 1    ...               0.003532         24.99             23.41
# 2    ...               0.004571         23.57             25.53
# 3    ...               0.009208         14.91             26.50
# 4    ...               0.005115         22.54             16.67
# ..   ...                    ...           ...               ...
# 494  ...               0.002701         14.50             28.46
# 495  ...               0.001812         16.01             28.48
# 496  ...               0.003563         14.38             22.15
# 497  ...               0.001541         14.06             24.34
# 498  ...               0.005255         22.75             22.88
#
#      critical perimeter  critical area  critical smoothness  critical density  \
# 0                184.60         2019.0               0.1622            0.6656
# 1                158.80         1956.0               0.1238            0.1866
# 2                152.50         1709.0               0.1444            0.4245
# 3                 98.87          567.7               0.2098            0.8663
# 4                152.20         1575.0               0.1374            0.2050
# ..                  ...            ...                  ...               ...
# 494               95.29          648.3               0.1118            0.1646
# 495              103.90          783.6               0.1216            0.1388
# 496               95.29          633.7               0.1533            0.3842
# 497               92.82          607.3               0.1276            0.2506
# 498              146.40         1600.0               0.1412            0.3089
#
#      critical symmetry  critical fractal dimension  target
# 0               0.4601                     0.11890       0
# 1               0.2750                     0.08902       0
# 2               0.3613                     0.08758       0
# 3               0.6638                     0.17300       0
# 4               0.2364                     0.07678       0
# ..                 ...                         ...     ...
# 494             0.2687                     0.07429       1
# 495             0.2369                     0.06599       1
# 496             0.3230                     0.10330       1
# 497             0.3035                     0.07661       1
# 498             0.2510                     0.09445       0
#
# [499 rows x 24 columns]

# %%
df.isnull().sum()
df.isna().sum()
# Out:
# S.no                          0
# avg rad                       0
# avg texture                   0
# avg perimeter                 0
# avg area                      0
# avg smoothness                0
# avg density                   0
# avg symmetry                  0
# avg fractal dimension         0
# rad err                       0
# texture err                   0
# perimeter err                 0
# area err                      0
# smoothness err                0
# symmetry err                  0
# fractal dimension err         0
# critical rad                  0
# critical texture              0
# critical perimeter            0
# critical area                 0
# critical smoothness           0
# critical density              0
# critical symmetry             0
# critical fractal dimension    0
# target                        0
# dtype: int64

# %%
col_list = list(df.columns)
col_list
# Out:
# ['S.no',
#  'avg rad',
#  'avg texture',
#  'avg perimeter',
#  'avg area',
#  'avg smoothness',
#  'avg density',
#  'avg symmetry',
#  'avg fractal dimension',
#  'rad err',
#  'texture err',
#  'perimeter err',
#  'area err',
#  'smoothness err',
#  'symmetry err',
#  'fractal dimension err',
#  'critical rad',
#  'critical texture',
#  'critical perimeter',
#  'critical area',
#  'critical smoothness',
#  'critical density',
#  'critical symmetry',
#  'critical fractal dimension',
#  'target']

# %%
df['target'].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
sns.countplot(df['target'],palette='Set2');
# Out:
# C:\Users\syedw\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
X = df.drop('target', axis=1)
y = df['target']

# %% [markdown]
# # Training the Data

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y)

df.shape

X_train.shape


X_test.shape


y_train.shape


y_test.shape


ss = StandardScaler()
X_train = ss.fit_transform(X_train)
X_test = ss.transform(X_test)

X_train
# Out:
# array([[ 1.46745009, -0.35324994,  1.45461963, ..., -0.89712664,
#         -0.95602546, -1.09465333],
#        [ 1.27320721,  0.2153259 ,  0.82931421, ...,  2.7727352 ,
#         -0.11793106,  1.64849105],
#        [-0.94671148, -1.31773412, -0.50306734, ..., -0.4858965 ,
#         -0.61629791,  0.04089056],
#        ...,
#        [-1.17564059,  1.15796479, -0.70508909, ...,  1.88173656,
#          1.20655743,  1.40333459],
#        [ 0.98184288, -0.87095321, -0.86141545, ...,  0.1529789 ,
#         -1.17901844,  1.06428841],
#        [ 1.73800268, -0.51185268, -0.42610667, ..., -0.03244184,
#          0.13499386, -0.38004831]])

# %%
from sklearn.metrics import accuracy_score

# %%
#Logistic Regression

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train, y_train)

y_pred = lr.predict(X_test)
y_pred

y_test

print(accuracy_score(y_test, y_pred))
# Out:
# 0.968

# %%
# Decision Tree 
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(X_train, y_train)

y_pred = dtc.predict(X_test)
y_pred

print(accuracy_score(y_test, y_pred))
# Out:
# 0.912

# %%
# Random Forest Classifier
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(X_train, y_train)

y_pred = rfc.predict(X_test)
y_pred

print(accuracy_score(y_test, y_pred))
# Out:
# 0.976

# %%
# Support Vector Machine
from sklearn import svm
svc = svm.SVC()
svc.fit(X_train,y_train)
y_pred = svc.predict(X_test)
y_pred

from sklearn.metrics import accuracy_score
print(accuracy_score(y_test, y_pred))
# Out:
# 0.968

# %%
#KNN
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier()
knn.fit(X_train,y_train)
y_pred=knn.predict(X_test)
accuracy_score(y_pred,y_test)
# Out:
# 0.944

# %%
#Naive Bayes
from sklearn.naive_bayes import GaussianNB
gnb=GaussianNB()
gnb.fit(X_train,y_train)
y_pred=gnb.predict(X_test)
accuracy_score(y_pred,y_test)
# Out:
# 0.96

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[43,  3],
#        [ 2, 77]], dtype=int64)
